# %%
import pandas as pd

# %%
df = pd.read_csv('data/BenchmarkingSample20230607.csv')
df
# Out:
#               Unit  Period  Days                  Account  Amount
# 0     00040302CD88       1    30                    Sales   89952
# 1     00040302CD88       2    31                    Sales   90594
# 2     00040302CD88       3    30                    Sales   81909
# 3     00040302CD88       4    31                    Sales   87418
# 4     00040302CD88       5    31                    Sales   91109
# ...            ...     ...   ...                      ...     ...
# 6043  0004030BEB57      20    30  Other Non-controllables    1455
# 6044  0004030BEB57      21    31  Other Non-controllables    7456
# 6045  0004030BEB57      22    31  Other Non-controllables    2037
# 6046  0004030BEB57      23    28  Other Non-controllables    2037
# 6047  0004030BEB57      24    31  Other Non-controllables    2037
#
# [6048 rows x 5 columns]

# %% [markdown]
# ## Mean Analysis

# %%
calculate = df.drop_duplicates(keep='first')
calculate
# Out:
#               Unit  Period  Days                  Account  Amount
# 0     00040302CD88       1    30                    Sales   89952
# 1     00040302CD88       2    31                    Sales   90594
# 2     00040302CD88       3    30                    Sales   81909
# 3     00040302CD88       4    31                    Sales   87418
# 4     00040302CD88       5    31                    Sales   91109
# ...            ...     ...   ...                      ...     ...
# 6043  0004030BEB57      20    30  Other Non-controllables    1455
# 6044  0004030BEB57      21    31  Other Non-controllables    7456
# 6045  0004030BEB57      22    31  Other Non-controllables    2037
# 6046  0004030BEB57      23    28  Other Non-controllables    2037
# 6047  0004030BEB57      24    31  Other Non-controllables    2037
#
# [6033 rows x 5 columns]

# %%
calculate = df.pivot_table(index=['Unit', 'Period'], columns='Account', values='Amount', aggfunc='sum').reset_index()

# %% [markdown]
# Calculate Total cost and profit based on 'calculate'

# %%
# Create L&P table
output = pd.DataFrame()
output['Unit'] = calculate['Unit']


output['Total Cost of Sales'] = calculate['Cost of Sales - Food'] + calculate['Cost of Sales - Paper']
output['Gross Profit'] = calculate['Sales'] - output['Total Cost of Sales']
output['Total Labor'] = calculate[['Crew Labor', 'Management Labor', 'Other Labor-related Costs']].sum(axis=1)
output['Total Prime Costs'] = output['Total Cost of Sales'] + output['Total Labor']
output['Total Controllable Costs'] =  calculate[['Crew Labor','Management Labor','Other Labor-related Costs','Advertising','Promotion','Outside Services','Maintenance & Repair','Other Controllables','Utilities']].sum(axis=1)
output['Controllable Profit'] = output['Gross Profit'] - output['Total Controllable Costs']
output['Total Non-controllable Costs'] = calculate['Rent'] + calculate['Other Non-controllables']
output['Store EBITDA'] = output['Gross Profit'] - output['Total Controllable Costs'] - output['Total Non-controllable Costs']

output
# Out:
#              Unit  Total Cost of Sales  Gross Profit  Total Labor  \
# 0    00040302CD88                22747         67205         7898
# 1    00040302CD88                22934         67660         9330
# 2    00040302CD88                21822         60087         8033
# 3    00040302CD88                23055         64363        49056
# 4    00040302CD88                23669         67440        42535
# ..            ...                  ...           ...          ...
# 211  0004030BEB57               109793        264704        94918
# 212  0004030BEB57               121644        303041       114744
# 213  0004030BEB57               112525        250680       103340
# 214  0004030BEB57               110105        247506       105045
# 215  0004030BEB57               120429        293092       117966
#
#      Total Prime Costs  Total Controllable Costs  Controllable Profit  \
# 0                30645                     34531                32674
# 1                32264                     29278                38382
# 2                29855                     27747                32340
# 3                72111                     71261                -6898
# 4                66204                     64950                 2490
# ..                 ...                       ...                  ...
# 211             204711                    139868               124836
# 212             236388                    156370               146671
# 213             215865                    148349               102331
# 214             215150                    141023               106483
# 215             238395                    167878               125214
#
#      Total Non-controllable Costs  Store EBITDA
# 0                            7269         25405
# 1                            7740         30642
# 2                            6944         25396
# 3                            7184        -14082
# 4                            6218         -3728
# ..                            ...           ...
# 211                         91047         33789
# 212                        120684         25987
# 213                         86448         15883
# 214                         84785         21698
# 215                         99031         26183
#
# [216 rows x 9 columns]

# %%
output.to_excel('data/RMS_calculation.xlsx', index=False)

# %% [markdown]
# # Mean Analysis

# %%
# Create a sample time series data
data = output
mean_data = pd.DataFrame(data)

# Calculate the SMA with a window size of 3
mean_data['Total Cost of Sales_SMA'] = output['Total Cost of Sales'].rolling(window=3).mean()
mean_data['Gross Profit_SMA'] = output['Gross Profit'].rolling(window=3).mean()
mean_data['Total Labor_SMA'] = output['Total Labor'].rolling(window=3).mean()
mean_data['Total Prime Costs_SMA'] = output['Total Prime Costs'].rolling(window=3).mean()
mean_data['Total Controllable Costs_SMA'] = output['Total Controllable Costs'].rolling(window=3).mean()
mean_data['Controllable Profit_SMA'] = output['Controllable Profit'].rolling(window=3).mean()
mean_data['Total Non-controllable Costs_SMA'] = output['Total Non-controllable Costs'].rolling(window=3).mean()
mean_data['Store EBITDA_SMA'] = output['Store EBITDA'].rolling(window=3).mean()


mean_data = mean_data.round(2)
mean_data
# Out:
#              Unit  Total Cost of Sales  Gross Profit  Total Labor  \
# 0    00040302CD88                22747         67205         7898
# 1    00040302CD88                22934         67660         9330
# 2    00040302CD88                21822         60087         8033
# 3    00040302CD88                23055         64363        49056
# 4    00040302CD88                23669         67440        42535
# ..            ...                  ...           ...          ...
# 211  0004030BEB57               109793        264704        94918
# 212  0004030BEB57               121644        303041       114744
# 213  0004030BEB57               112525        250680       103340
# 214  0004030BEB57               110105        247506       105045
# 215  0004030BEB57               120429        293092       117966
#
#      Total Prime Costs  Total Controllable Costs  Controllable Profit  \
# 0                30645                     34531                32674
# 1                32264                     29278                38382
# 2                29855                     27747                32340
# 3                72111                     71261                -6898
# 4                66204                     64950                 2490
# ..                 ...                       ...                  ...
# 211             204711                    139868               124836
# 212             236388                    156370               146671
# 213             215865                    148349               102331
# 214             215150                    141023               106483
# 215             238395                    167878               125214
#
#      Total Non-controllable Costs  Store EBITDA  Total Cost of Sales_SMA  \
# 0                            7269         25405                      NaN
# 1                            7740         30642                      NaN
# 2                            6944         25396                 22501.00
# 3                            7184        -14082                 22603.67
# 4                            6218         -3728                 22848.67
# ..                            ...           ...                      ...
# 211                         91047         33789                110990.67
# 212                        120684         25987                114948.33
# 213                         86448         15883                114654.00
# 214                         84785         21698                114758.00
# 215                         99031         26183                114353.00
#
#      Gross Profit_SMA  Total Labor_SMA  Total Prime Costs_SMA  \
# 0                 NaN              NaN                    NaN
# 1                 NaN              NaN                    NaN
# 2            64984.00          8420.33               30921.33
# 3            64036.67         22139.67               44743.33
# 4            63963.33         33208.00               56056.67
# ..                ...              ...                    ...
# 211         266104.33         98210.00              209200.67
# 212         281048.33        104379.67              219328.00
# 213         272808.33        104334.00              218988.00
# 214         267075.67        107709.67              222467.67
# 215         263759.33        108783.67              223136.67
#
#      Total Controllable Costs_SMA  Controllable Profit_SMA  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2                        30518.67                 34465.33
# 3                        42762.00                 21274.67
# 4                        54652.67                  9310.67
# ..                            ...                      ...
# 211                     141025.67                125078.67
# 212                     146175.67                134872.67
# 213                     148195.67                124612.67
# 214                     148580.67                118495.00
# 215                     152416.67                111342.67
#
#      Total Non-controllable Costs_SMA  Store EBITDA_SMA
# 0                                 NaN               NaN
# 1                                 NaN               NaN
# 2                             7317.67          27147.67
# 3                             7289.33          13985.33
# 4                             6782.00           2528.67
# ..                                ...               ...
# 211                          91994.67          33084.00
# 212                         102668.33          32204.33
# 213                          99393.00          25219.67
# 214                          97305.67          21189.33
# 215                          90088.00          21254.67
#
# [216 rows x 17 columns]

# %%
mean_data.columns
# Out:
# Index(['Unit', 'Total Cost of Sales', 'Gross Profit', 'Total Labor',
#        'Total Prime Costs', 'Total Controllable Costs', 'Controllable Profit',
#        'Total Non-controllable Costs', 'Store EBITDA',
#        'Total Cost of Sales_SMA', 'Gross Profit_SMA', 'Total Labor_SMA',
#        'Total Prime Costs_SMA', 'Total Controllable Costs_SMA',
#        'Controllable Profit_SMA', 'Total Non-controllable Costs_SMA',
#        'Store EBITDA_SMA'],
#       dtype='object')

# %%
mean_data = mean_data[['Unit',
       'Total Cost of Sales_SMA', 'Gross Profit_SMA', 'Total Labor_SMA',
       'Total Prime Costs_SMA', 'Total Controllable Costs_SMA',
       'Controllable Profit_SMA', 'Total Non-controllable Costs_SMA',
       'Store EBITDA_SMA']]

mean_data
# Out:
#              Unit  Total Cost of Sales_SMA  Gross Profit_SMA  Total Labor_SMA  \
# 0    00040302CD88                      NaN               NaN              NaN
# 1    00040302CD88                      NaN               NaN              NaN
# 2    00040302CD88                 22501.00          64984.00          8420.33
# 3    00040302CD88                 22603.67          64036.67         22139.67
# 4    00040302CD88                 22848.67          63963.33         33208.00
# ..            ...                      ...               ...              ...
# 211  0004030BEB57                110990.67         266104.33         98210.00
# 212  0004030BEB57                114948.33         281048.33        104379.67
# 213  0004030BEB57                114654.00         272808.33        104334.00
# 214  0004030BEB57                114758.00         267075.67        107709.67
# 215  0004030BEB57                114353.00         263759.33        108783.67
#
#      Total Prime Costs_SMA  Total Controllable Costs_SMA  \
# 0                      NaN                           NaN
# 1                      NaN                           NaN
# 2                 30921.33                      30518.67
# 3                 44743.33                      42762.00
# 4                 56056.67                      54652.67
# ..                     ...                           ...
# 211              209200.67                     141025.67
# 212              219328.00                     146175.67
# 213              218988.00                     148195.67
# 214              222467.67                     148580.67
# 215              223136.67                     152416.67
#
#      Controllable Profit_SMA  Total Non-controllable Costs_SMA  \
# 0                        NaN                               NaN
# 1                        NaN                               NaN
# 2                   34465.33                           7317.67
# 3                   21274.67                           7289.33
# 4                    9310.67                           6782.00
# ..                       ...                               ...
# 211                125078.67                          91994.67
# 212                134872.67                         102668.33
# 213                124612.67                          99393.00
# 214                118495.00                          97305.67
# 215                111342.67                          90088.00
#
#      Store EBITDA_SMA
# 0                 NaN
# 1                 NaN
# 2            27147.67
# 3            13985.33
# 4             2528.67
# ..                ...
# 211          33084.00
# 212          32204.33
# 213          25219.67
# 214          21189.33
# 215          21254.67
#
# [216 rows x 9 columns]

# %%
# Export mean_data 
mean_data.to_excel('data/RMS_SMA.xlsx', index=False)
