# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('data/BenchmarkingSample20230607.csv')
df
# Out:
#               Unit  Period  Days                  Account  Amount
# 0     00040302CD88       1    30                    Sales   89952
# 1     00040302CD88       2    31                    Sales   90594
# 2     00040302CD88       3    30                    Sales   81909
# 3     00040302CD88       4    31                    Sales   87418
# 4     00040302CD88       5    31                    Sales   91109
# ...            ...     ...   ...                      ...     ...
# 6043  0004030BEB57      20    30  Other Non-controllables    1455
# 6044  0004030BEB57      21    31  Other Non-controllables    7456
# 6045  0004030BEB57      22    31  Other Non-controllables    2037
# 6046  0004030BEB57      23    28  Other Non-controllables    2037
# 6047  0004030BEB57      24    31  Other Non-controllables    2037
#
# [6048 rows x 5 columns]

# %%
# Convert the 'Days' column to datetime format
dates = pd.date_range(start='4/1/2021', periods=df['Period'].max(), freq='M')
df['Date'] = dates.array[df['Period'] - 1]
df
# Out:
#               Unit  Period  Days                  Account  Amount       Date
# 0     00040302CD88       1    30                    Sales   89952 2021-04-30
# 1     00040302CD88       2    31                    Sales   90594 2021-05-31
# 2     00040302CD88       3    30                    Sales   81909 2021-06-30
# 3     00040302CD88       4    31                    Sales   87418 2021-07-31
# 4     00040302CD88       5    31                    Sales   91109 2021-08-31
# ...            ...     ...   ...                      ...     ...        ...
# 6043  0004030BEB57      20    30  Other Non-controllables    1455 2022-11-30
# 6044  0004030BEB57      21    31  Other Non-controllables    7456 2022-12-31
# 6045  0004030BEB57      22    31  Other Non-controllables    2037 2023-01-31
# 6046  0004030BEB57      23    28  Other Non-controllables    2037 2023-02-28
# 6047  0004030BEB57      24    31  Other Non-controllables    2037 2023-03-31
#
# [6048 rows x 6 columns]

# %%
# reshape df
unmelt = df.pivot_table(index=['Unit', 'Date', 'Days', 'Period'], columns='Account', values='Amount', aggfunc='sum')
unmelt = unmelt.reset_index()
unmelt
# Out:
# Account          Unit       Date  Days  Period  Advertising  \
# 0        00040302CD88 2021-04-30    30       1         3778
# 1        00040302CD88 2021-05-31    31       2         3805
# 2        00040302CD88 2021-06-30    30       3         3440
# 3        00040302CD88 2021-07-31    31       4         3672
# 4        00040302CD88 2021-08-31    31       5         3827
# ..                ...        ...   ...     ...          ...
# 211      0004030BEB57 2022-11-30    30      20        15729
# 212      0004030BEB57 2022-12-31    31      21        12227
# 213      0004030BEB57 2023-01-31    31      22        15255
# 214      0004030BEB57 2023-02-28    28      23        15020
# 215      0004030BEB57 2023-03-31    31      24        17368
#
# Account  Cost of Sales - Food  Cost of Sales - Paper  Crew Labor  \
# 0                       20557                   2190         486
# 1                       20876                   2058        1376
# 2                       19531                   2291         178
# 3                       20999                   2056       36597
# 4                       21357                   2312       29942
# ..                        ...                    ...         ...
# 211                     99236                  10557       75243
# 212                    108507                  13137       94509
# 213                    101713                  10812       82894
# 214                     98547                  11558       83338
# 215                    110366                  10063       94112
#
# Account  Maintenance & Repair  Management Labor  Other Controllables  \
# 0                        5135              3983                 3167
# 1                        1553              4255                 3899
# 2                        2321              4241                 3646
# 3                        3412              5515                 2581
# 4                        3345              5484                 3772
# ..                        ...               ...                  ...
# 211                      8789              3997                 2729
# 212                      1704              4989                 6187
# 213                      3256              4278                 4408
# 214                      3605              5253                 3443
# 215                      5267              5433                 4094
#
# Account  Other Labor-related Costs  Other Non-controllables  Outside Services  \
# 0                             3429                     7879              8462
# 1                             3699                     7918              5329
# 2                             3614                     7471              5062
# 3                             6944                     7537              5967
# 4                             7109                     6385              5727
# ..                             ...                      ...               ...
# 211                          15678                    26672             11476
# 212                          15246                    39347             16172
# 213                          16168                    28140             11189
# 214                          16454                    27999             10646
# 215                          18421                    30603             14421
#
# Account  Promotion   Rent   Sales  Utilities
# 0              401   -610   89952       5690
# 1              445   -178   90594       4917
# 2              553   -527   81909       4692
# 3              874   -353   87418       5699
# 4              635   -167   91109       5109
# ..             ...    ...     ...        ...
# 211             -3  64375  374497       6230
# 212          -1144  81337  424685       6480
# 213           2665  58308  363205       8236
# 214            608  56786  357611       2656
# 215           1761  68428  413521       7001
#
# [216 rows x 18 columns]

# %%
columns_to_average = unmelt.columns.drop(['Unit', 'Date', 'Days', 'Sales'])
for col in columns_to_average:
    unmelt[f'Average daily {col}'] = (unmelt[col] / unmelt['Days']).round(2)
old_columns = unmelt.columns
old_columns
# Out:
# Index(['Unit', 'Date', 'Days', 'Period', 'Advertising', 'Cost of Sales - Food',
#        'Cost of Sales - Paper', 'Crew Labor', 'Maintenance & Repair',
#        'Management Labor', 'Other Controllables', 'Other Labor-related Costs',
#        'Other Non-controllables', 'Outside Services', 'Promotion', 'Rent',
#        'Sales', 'Utilities', 'Average daily Period',
#        'Average daily Advertising', 'Average daily Cost of Sales - Food',
#        'Average daily Cost of Sales - Paper', 'Average daily Crew Labor',
#        'Average daily Maintenance & Repair', 'Average daily Management Labor',
#        'Average daily Other Controllables',
#        'Average daily Other Labor-related Costs',
#        'Average daily Other Non-controllables',
#        'Average daily Outside Services', 'Average daily Promotion',
#        'Average daily Rent', 'Average daily Utilities'],
#       dtype='object', name='Account')

# %%
# Add columns to the dataframe as per the Example P & L excel file
unmelt['Total Cost of Sales'] = unmelt[['Cost of Sales - Food', 'Cost of Sales - Paper']].sum(axis=1)
unmelt['Gross Profit'] = unmelt['Sales'] - unmelt['Total Cost of Sales']
unmelt['Total Labor'] = unmelt[['Crew Labor', 'Management Labor', 'Other Labor-related Costs']].sum(axis=1)
unmelt['Total Prime Costs'] = unmelt['Total Cost of Sales'] + unmelt['Total Labor']
unmelt['Total Controllable Costs'] = unmelt[['Crew Labor','Management Labor','Other Labor-related Costs','Advertising','Promotion','Outside Services','Maintenance & Repair','Other Controllables','Utilities']].sum(axis = 1)
unmelt['Controllable Profit'] = unmelt['Gross Profit'] - unmelt['Total Controllable Costs']
unmelt['Total Non-controllable Costs'] = unmelt['Cost of Sales - Food'] + unmelt['Cost of Sales - Paper']
unmelt['Store EBITDA'] = unmelt['Gross Profit'] - unmelt['Total Controllable Costs'] - unmelt['Total Non-controllable Costs']
new_columns = unmelt.columns.drop(old_columns)
new_columns
# Out:
# Index(['Total Cost of Sales', 'Gross Profit', 'Total Labor',
#        'Total Prime Costs', 'Total Controllable Costs', 'Controllable Profit',
#        'Total Non-controllable Costs', 'Store EBITDA'],
#       dtype='object', name='Account')

# %%
unmelt[pd.Index(['Unit']).append(new_columns)]
unmelt
# Out:
# Account          Unit       Date  Days  Period  Advertising  \
# 0        00040302CD88 2021-04-30    30       1         3778
# 1        00040302CD88 2021-05-31    31       2         3805
# 2        00040302CD88 2021-06-30    30       3         3440
# 3        00040302CD88 2021-07-31    31       4         3672
# 4        00040302CD88 2021-08-31    31       5         3827
# ..                ...        ...   ...     ...          ...
# 211      0004030BEB57 2022-11-30    30      20        15729
# 212      0004030BEB57 2022-12-31    31      21        12227
# 213      0004030BEB57 2023-01-31    31      22        15255
# 214      0004030BEB57 2023-02-28    28      23        15020
# 215      0004030BEB57 2023-03-31    31      24        17368
#
# Account  Cost of Sales - Food  Cost of Sales - Paper  Crew Labor  \
# 0                       20557                   2190         486
# 1                       20876                   2058        1376
# 2                       19531                   2291         178
# 3                       20999                   2056       36597
# 4                       21357                   2312       29942
# ..                        ...                    ...         ...
# 211                     99236                  10557       75243
# 212                    108507                  13137       94509
# 213                    101713                  10812       82894
# 214                     98547                  11558       83338
# 215                    110366                  10063       94112
#
# Account  Maintenance & Repair  Management Labor  ...  Average daily Rent  \
# 0                        5135              3983  ...              -20.33
# 1                        1553              4255  ...               -5.74
# 2                        2321              4241  ...              -17.57
# 3                        3412              5515  ...              -11.39
# 4                        3345              5484  ...               -5.39
# ..                        ...               ...  ...                 ...
# 211                      8789              3997  ...             2145.83
# 212                      1704              4989  ...             2623.77
# 213                      3256              4278  ...             1880.90
# 214                      3605              5253  ...             2028.07
# 215                      5267              5433  ...             2207.35
#
# Account  Average daily Utilities  Total Cost of Sales  Gross Profit  \
# 0                         189.67                22747         67205
# 1                         158.61                22934         67660
# 2                         156.40                21822         60087
# 3                         183.84                23055         64363
# 4                         164.81                23669         67440
# ..                           ...                  ...           ...
# 211                       207.67               109793        264704
# 212                       209.03               121644        303041
# 213                       265.68               112525        250680
# 214                        94.86               110105        247506
# 215                       225.84               120429        293092
#
# Account  Total Labor  Total Prime Costs  Total Controllable Costs  \
# 0               7898              30645                     34531
# 1               9330              32264                     29278
# 2               8033              29855                     27747
# 3              49056              72111                     71261
# 4              42535              66204                     64950
# ..               ...                ...                       ...
# 211            94918             204711                    139868
# 212           114744             236388                    156370
# 213           103340             215865                    148349
# 214           105045             215150                    141023
# 215           117966             238395                    167878
#
# Account  Controllable Profit  Total Non-controllable Costs  Store EBITDA
# 0                      32674                         22747          9927
# 1                      38382                         22934         15448
# 2                      32340                         21822         10518
# 3                      -6898                         23055        -29953
# 4                       2490                         23669        -21179
# ..                       ...                           ...           ...
# 211                   124836                        109793         15043
# 212                   146671                        121644         25027
# 213                   102331                        112525        -10194
# 214                   106483                        110105         -3622
# 215                   125214                        120429          4785
#
# [216 rows x 40 columns]

# %%
unmelt['Adjusted daily Rent'] = unmelt['Average daily Rent']
unmelt.loc[unmelt['Adjusted daily Rent'] < 0, 'Adjusted daily Rent'] = np.nan

# Calculate the average of positive values within each group
unmelt['Adjusted daily Rent'] = unmelt.groupby('Unit')['Adjusted daily Rent'].transform(lambda x: x[x > 0].mean())
averaged_columns = [column for column in unmelt.columns if (('Average daily' in column or 'Adjusted daily' in column) and (column not in ['Average daily Rent', 'Average daily Advertising', 'Average daily Period']))]
unmelt.loc[:, averaged_columns]
# Out:
# Account  Average daily Cost of Sales - Food  \
# 0                                    685.23
# 1                                    673.42
# 2                                    651.03
# 3                                    677.39
# 4                                    688.94
# ..                                      ...
# 211                                 3307.87
# 212                                 3500.23
# 213                                 3281.06
# 214                                 3519.54
# 215                                 3560.19
#
# Account  Average daily Cost of Sales - Paper  Average daily Crew Labor  \
# 0                                      73.00                     16.20
# 1                                      66.39                     44.39
# 2                                      76.37                      5.93
# 3                                      66.32                   1180.55
# 4                                      74.58                    965.87
# ..                                       ...                       ...
# 211                                   351.90                   2508.10
# 212                                   423.77                   3048.68
# 213                                   348.77                   2674.00
# 214                                   412.79                   2976.36
# 215                                   324.61                   3035.87
#
# Account  Average daily Maintenance & Repair  Average daily Management Labor  \
# 0                                    171.17                          132.77
# 1                                     50.10                          137.26
# 2                                     77.37                          141.37
# 3                                    110.06                          177.90
# 4                                    107.90                          176.90
# ..                                      ...                             ...
# 211                                  292.97                          133.23
# 212                                   54.97                          160.94
# 213                                  105.03                          138.00
# 214                                  128.75                          187.61
# 215                                  169.90                          175.26
#
# Account  Average daily Other Controllables  \
# 0                                   105.57
# 1                                   125.77
# 2                                   121.53
# 3                                    83.26
# 4                                   121.68
# ..                                     ...
# 211                                  90.97
# 212                                 199.58
# 213                                 142.19
# 214                                 122.96
# 215                                 132.06
#
# Account  Average daily Other Labor-related Costs  \
# 0                                         114.30
# 1                                         119.32
# 2                                         120.47
# 3                                         224.00
# 4                                         229.32
# ..                                           ...
# 211                                       522.60
# 212                                       491.81
# 213                                       521.55
# 214                                       587.64
# 215                                       594.23
#
# Account  Average daily Other Non-controllables  \
# 0                                       262.63
# 1                                       255.42
# 2                                       249.03
# 3                                       243.13
# 4                                       205.97
# ..                                         ...
# 211                                     889.07
# 212                                    1269.26
# 213                                     907.74
# 214                                     999.96
# 215                                     987.19
#
# Account  Average daily Outside Services  Average daily Promotion  \
# 0                                282.07                    13.37
# 1                                171.90                    14.35
# 2                                168.73                    18.43
# 3                                192.48                    28.19
# 4                                184.74                    20.48
# ..                                  ...                      ...
# 211                              382.53                    -0.10
# 212                              521.68                   -36.90
# 213                              360.94                    85.97
# 214                              380.21                    21.71
# 215                              465.19                    56.81
#
# Account  Average daily Utilities  Adjusted daily Rent
# 0                         189.67            15.003333
# 1                         158.61            15.003333
# 2                         156.40            15.003333
# 3                         183.84            15.003333
# 4                         164.81            15.003333
# ..                           ...                  ...
# 211                       207.67          2175.308333
# 212                       209.03          2175.308333
# 213                       265.68          2175.308333
# 214                        94.86          2175.308333
# 215                       225.84          2175.308333
#
# [216 rows x 12 columns]

# %%
unmelt['Average Daily Cost'] = unmelt.loc[:, averaged_columns].sum(axis=1)
unmelt = unmelt.drop('Average daily Rent', axis=1)
unmelt
# Out:
# Account          Unit       Date  Days  Period  Advertising  \
# 0        00040302CD88 2021-04-30    30       1         3778
# 1        00040302CD88 2021-05-31    31       2         3805
# 2        00040302CD88 2021-06-30    30       3         3440
# 3        00040302CD88 2021-07-31    31       4         3672
# 4        00040302CD88 2021-08-31    31       5         3827
# ..                ...        ...   ...     ...          ...
# 211      0004030BEB57 2022-11-30    30      20        15729
# 212      0004030BEB57 2022-12-31    31      21        12227
# 213      0004030BEB57 2023-01-31    31      22        15255
# 214      0004030BEB57 2023-02-28    28      23        15020
# 215      0004030BEB57 2023-03-31    31      24        17368
#
# Account  Cost of Sales - Food  Cost of Sales - Paper  Crew Labor  \
# 0                       20557                   2190         486
# 1                       20876                   2058        1376
# 2                       19531                   2291         178
# 3                       20999                   2056       36597
# 4                       21357                   2312       29942
# ..                        ...                    ...         ...
# 211                     99236                  10557       75243
# 212                    108507                  13137       94509
# 213                    101713                  10812       82894
# 214                     98547                  11558       83338
# 215                    110366                  10063       94112
#
# Account  Maintenance & Repair  Management Labor  ...  Total Cost of Sales  \
# 0                        5135              3983  ...                22747
# 1                        1553              4255  ...                22934
# 2                        2321              4241  ...                21822
# 3                        3412              5515  ...                23055
# 4                        3345              5484  ...                23669
# ..                        ...               ...  ...                  ...
# 211                      8789              3997  ...               109793
# 212                      1704              4989  ...               121644
# 213                      3256              4278  ...               112525
# 214                      3605              5253  ...               110105
# 215                      5267              5433  ...               120429
#
# Account  Gross Profit  Total Labor  Total Prime Costs  \
# 0               67205         7898              30645
# 1               67660         9330              32264
# 2               60087         8033              29855
# 3               64363        49056              72111
# 4               67440        42535              66204
# ..                ...          ...                ...
# 211            264704        94918             204711
# 212            303041       114744             236388
# 213            250680       103340             215865
# 214            247506       105045             215150
# 215            293092       117966             238395
#
# Account  Total Controllable Costs  Controllable Profit  \
# 0                           34531                32674
# 1                           29278                38382
# 2                           27747                32340
# 3                           71261                -6898
# 4                           64950                 2490
# ..                            ...                  ...
# 211                        139868               124836
# 212                        156370               146671
# 213                        148349               102331
# 214                        141023               106483
# 215                        167878               125214
#
# Account  Total Non-controllable Costs  Store EBITDA  Adjusted daily Rent  \
# 0                               22747          9927            15.003333
# 1                               22934         15448            15.003333
# 2                               21822         10518            15.003333
# 3                               23055        -29953            15.003333
# 4                               23669        -21179            15.003333
# ..                                ...           ...                  ...
# 211                            109793         15043          2175.308333
# 212                            121644         25027          2175.308333
# 213                            112525        -10194          2175.308333
# 214                            110105         -3622          2175.308333
# 215                            120429          4785          2175.308333
#
# Account  Average Daily Cost
# 0               2060.983333
# 1               1831.933333
# 2               1801.663333
# 3               3182.123333
# 4               2956.193333
# ..                      ...
# 211            10862.118333
# 212            12018.358333
# 213            11006.238333
# 214            11607.698333
# 215            11902.458333
#
# [216 rows x 41 columns]

# %%
unmelt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 216 entries, 0 to 215
# Data columns (total 41 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   Unit                                     216 non-null    object
#  1   Date                                     216 non-null    datetime64[ns]
#  2   Days                                     216 non-null    int64
#  3   Period                                   216 non-null    int64
#  4   Advertising                              216 non-null    int64
#  5   Cost of Sales - Food                     216 non-null    int64
#  6   Cost of Sales - Paper                    216 non-null    int64
#  7   Crew Labor                               216 non-null    int64
#  8   Maintenance & Repair                     216 non-null    int64
#  9   Management Labor                         216 non-null    int64
#  10  Other Controllables                      216 non-null    int64
#  11  Other Labor-related Costs                216 non-null    int64
#  12  Other Non-controllables                  216 non-null    int64
#  13  Outside Services                         216 non-null    int64
#  14  Promotion                                216 non-null    int64
#  15  Rent                                     216 non-null    int64
#  16  Sales                                    216 non-null    int64
#  17  Utilities                                216 non-null    int64
#  18  Average daily Period                     216 non-null    float64
#  19  Average daily Advertising                216 non-null    float64
#  20  Average daily Cost of Sales - Food       216 non-null    float64
#  21  Average daily Cost of Sales - Paper      216 non-null    float64
#  22  Average daily Crew Labor                 216 non-null    float64
#  23  Average daily Maintenance & Repair       216 non-null    float64
#  24  Average daily Management Labor           216 non-null    float64
#  25  Average daily Other Controllables        216 non-null    float64
#  26  Average daily Other Labor-related Costs  216 non-null    float64
#  27  Average daily Other Non-controllables    216 non-null    float64
#  28  Average daily Outside Services           216 non-null    float64
#  29  Average daily Promotion                  216 non-null    float64
#  30  Average daily Utilities                  216 non-null    float64
#  31  Total Cost of Sales                      216 non-null    int64
#  32  Gross Profit                             216 non-null    int64
#  33  Total Labor                              216 non-null    int64
#  34  Total Prime Costs                        216 non-null    int64
#  35  Total Controllable Costs                 216 non-null    int64
#  36  Controllable Profit                      216 non-null    int64
#  37  Total Non-controllable Costs             216 non-null    int64
#  38  Store EBITDA                             216 non-null    int64
#  39  Adjusted daily Rent                      192 non-null    float64
#  40  Average Daily Cost                       216 non-null    float64
# dtypes: datetime64[ns](1), float64(15), int64(24), object(1)
# memory usage: 69.3+ KB

# %%
unmelt.to_csv("data/BenchmarkingSample20230607_with_features.csv", index=False)
